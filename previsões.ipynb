# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv(r".\data\dataset_aula03_student_habits_performance (1).csv")

# %%
sns.lmplot(data=df,x="study_hours_per_day",y="exam_score");

# %%
X = df[["study_hours_per_day"]]
y = df["exam_score"]

# %%
from sklearn.linear_model import LinearRegression

# %%
modelo = LinearRegression()
modelo.fit(x,y)
# Out:
# LinearRegression()

# %%
novo_aluno = pd.DataFrame({"study_hours_per_day":[2]})
modelo.predict(novo_aluno)
# Out:
# array([54.89066285])

# %%
modelo.coef_
# Out:
# array([9.49025041])

# %%
modelo.intercept_
# Out:
# np.float64(35.91016203402567)

# %%
modelo.score(x,y)
# Out:
# 0.6813157156535874
